# %% [markdown]
# # Movie Recommender: A Content-Based Approach

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Reading and cleaning data

# %% [markdown]
# ### Movie Rating Dataset

# %%
movie_rating_df = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/movie_rating_df.csv')
movie_rating_df
# Out:
#            tconst  titleType            primaryTitle           originalTitle  \
# 0       tt0000001      short              Carmencita              Carmencita
# 1       tt0000002      short  Le clown et ses chiens  Le clown et ses chiens
# 2       tt0000003      short          Pauvre Pierrot          Pauvre Pierrot
# 3       tt0000004      short             Un bon bock             Un bon bock
# 4       tt0000005      short        Blacksmith Scene        Blacksmith Scene
# ...           ...        ...                     ...                     ...
# 751609  tt9916538      movie     Kuambil Lagi Hatiku     Kuambil Lagi Hatiku
# 751610  tt9916544      short         My Sweet Prince         My Sweet Prince
# 751611  tt9916576  tvEpisode        Destinee's Story        Destinee's Story
# 751612  tt9916720      short               The Nun 2               The Nun 2
# 751613  tt9916766  tvEpisode          Episode #10.15          Episode #10.15
#
#         isAdult  startYear  endYear  runtimeMinutes                    genres  \
# 0             0     1894.0      NaN             1.0         Documentary,Short
# 1             0     1892.0      NaN             5.0           Animation,Short
# 2             0     1892.0      NaN             4.0  Animation,Comedy,Romance
# 3             0     1892.0      NaN            12.0           Animation,Short
# 4             0     1893.0      NaN             1.0              Comedy,Short
# ...         ...        ...      ...             ...                       ...
# 751609        0     2019.0      NaN           123.0                       NaN
# 751610        0     2019.0      NaN            12.0               Drama,Short
# 751611        0     2019.0      NaN            85.0                       NaN
# 751612        0     2019.0      NaN            10.0     Comedy,Horror,Mystery
# 751613        0     2019.0      NaN            43.0         Family,Reality-TV
#
#         averageRating  numVotes
# 0                 5.6      1608
# 1                 6.0       197
# 2                 6.5      1285
# 3                 6.1       121
# 4                 6.1      2050
# ...               ...       ...
# 751609            8.4         5
# 751610            7.2        19
# 751611            6.0         9
# 751612            5.6        49
# 751613            6.8        13
#
# [751614 rows x 11 columns]

# %%
print(movie_rating_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751614 entries, 0 to 751613
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          751614 non-null  object
#  1   titleType       751614 non-null  object
#  2   primaryTitle    751614 non-null  object
#  3   originalTitle   751614 non-null  object
#  4   isAdult         751614 non-null  int64
#  5   startYear       751614 non-null  float64
#  6   endYear         16072 non-null   float64
#  7   runtimeMinutes  751614 non-null  float64
#  8   genres          486766 non-null  object
#  9   averageRating   751614 non-null  float64
#  10  numVotes        751614 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 63.1+ MB
# None

# %%
movie_rating_df['endYear'] = movie_rating_df['endYear'].fillna(movie_rating_df['startYear'])
movie_rating_df
# Out:
#            tconst  titleType            primaryTitle           originalTitle  \
# 0       tt0000001      short              Carmencita              Carmencita
# 1       tt0000002      short  Le clown et ses chiens  Le clown et ses chiens
# 2       tt0000003      short          Pauvre Pierrot          Pauvre Pierrot
# 3       tt0000004      short             Un bon bock             Un bon bock
# 4       tt0000005      short        Blacksmith Scene        Blacksmith Scene
# ...           ...        ...                     ...                     ...
# 751609  tt9916538      movie     Kuambil Lagi Hatiku     Kuambil Lagi Hatiku
# 751610  tt9916544      short         My Sweet Prince         My Sweet Prince
# 751611  tt9916576  tvEpisode        Destinee's Story        Destinee's Story
# 751612  tt9916720      short               The Nun 2               The Nun 2
# 751613  tt9916766  tvEpisode          Episode #10.15          Episode #10.15
#
#         isAdult  startYear  endYear  runtimeMinutes                    genres  \
# 0             0     1894.0   1894.0             1.0         Documentary,Short
# 1             0     1892.0   1892.0             5.0           Animation,Short
# 2             0     1892.0   1892.0             4.0  Animation,Comedy,Romance
# 3             0     1892.0   1892.0            12.0           Animation,Short
# 4             0     1893.0   1893.0             1.0              Comedy,Short
# ...         ...        ...      ...             ...                       ...
# 751609        0     2019.0   2019.0           123.0                       NaN
# 751610        0     2019.0   2019.0            12.0               Drama,Short
# 751611        0     2019.0   2019.0            85.0                       NaN
# 751612        0     2019.0   2019.0            10.0     Comedy,Horror,Mystery
# 751613        0     2019.0   2019.0            43.0         Family,Reality-TV
#
#         averageRating  numVotes
# 0                 5.6      1608
# 1                 6.0       197
# 2                 6.5      1285
# 3                 6.1       121
# 4                 6.1      2050
# ...               ...       ...
# 751609            8.4         5
# 751610            7.2        19
# 751611            6.0         9
# 751612            5.6        49
# 751613            6.8        13
#
# [751614 rows x 11 columns]

# %%
movie_rating_df['genres'] = movie_rating_df['genres'].fillna('Unknown')
movie_rating_df
# Out:
#            tconst  titleType            primaryTitle           originalTitle  \
# 0       tt0000001      short              Carmencita              Carmencita
# 1       tt0000002      short  Le clown et ses chiens  Le clown et ses chiens
# 2       tt0000003      short          Pauvre Pierrot          Pauvre Pierrot
# 3       tt0000004      short             Un bon bock             Un bon bock
# 4       tt0000005      short        Blacksmith Scene        Blacksmith Scene
# ...           ...        ...                     ...                     ...
# 751609  tt9916538      movie     Kuambil Lagi Hatiku     Kuambil Lagi Hatiku
# 751610  tt9916544      short         My Sweet Prince         My Sweet Prince
# 751611  tt9916576  tvEpisode        Destinee's Story        Destinee's Story
# 751612  tt9916720      short               The Nun 2               The Nun 2
# 751613  tt9916766  tvEpisode          Episode #10.15          Episode #10.15
#
#         isAdult  startYear  endYear  runtimeMinutes                    genres  \
# 0             0     1894.0   1894.0             1.0         Documentary,Short
# 1             0     1892.0   1892.0             5.0           Animation,Short
# 2             0     1892.0   1892.0             4.0  Animation,Comedy,Romance
# 3             0     1892.0   1892.0            12.0           Animation,Short
# 4             0     1893.0   1893.0             1.0              Comedy,Short
# ...         ...        ...      ...             ...                       ...
# 751609        0     2019.0   2019.0           123.0                   Unknown
# 751610        0     2019.0   2019.0            12.0               Drama,Short
# 751611        0     2019.0   2019.0            85.0                   Unknown
# 751612        0     2019.0   2019.0            10.0     Comedy,Horror,Mystery
# 751613        0     2019.0   2019.0            43.0         Family,Reality-TV
#
#         averageRating  numVotes
# 0                 5.6      1608
# 1                 6.0       197
# 2                 6.5      1285
# 3                 6.1       121
# 4                 6.1      2050
# ...               ...       ...
# 751609            8.4         5
# 751610            7.2        19
# 751611            6.0         9
# 751612            5.6        49
# 751613            6.8        13
#
# [751614 rows x 11 columns]

# %%
print(movie_rating_df.isnull().sum())
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# averageRating     0
# numVotes          0
# dtype: int64

# %% [markdown]
# ### Director Writers Dataset

# %%
director_writers = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/directors_writers.csv')
director_writers['director_name'] = director_writers['director_name'].apply(lambda row: row.split(','))
director_writers['writer_name'] = director_writers['writer_name'].apply(lambda row: row.split(','))
director_writers
# Out:
#         tconst                      director_name  \
# 0    tt0011414                   [David Kirkland]
# 1    tt0011890                [Roy William Neill]
# 2    tt0014341  [Buster Keaton, John G. Blystone]
# 3    tt0018054                 [Cecil B. DeMille]
# 4    tt0024151                      [James Cruze]
# ..         ...                                ...
# 981  tt9236688                       [Kai Wessel]
# 982  tt9278408                     [Bahadir Ince]
# 983  tt9285882                           [Rapman]
# 984  tt9310372                      [Sujoy Ghosh]
# 985  tt9355200                  [Johannes Nyholm]
#
#                                            writer_name
# 0                           [John Emerson, Anita Loos]
# 1     [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2    [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                  [Jeanie Macpherson]
# 4                 [Max Miller, Wells Root, Jack Jevne]
# ..                                                 ...
# 981                                [Christian Jeltsch]
# 982        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 983                                           [Rapman]
# 984  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 985                                  [Johannes Nyholm]
#
# [986 rows x 3 columns]

# %%
print(director_writers.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         986 non-null    object
#  1   director_name  986 non-null    object
#  2   writer_name    986 non-null    object
# dtypes: object(3)
# memory usage: 23.2+ KB
# None

# %%
print(director_writers.isnull().sum())
# Out:
# tconst           0
# director_name    0
# writer_name      0
# dtype: int64

# %% [markdown]
# ### Actor Dataset

# %%
name_df = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/actor_name.csv')
name_df = name_df[['nconst','primaryName','knownForTitles']]
name_df
# Out:
#          nconst          primaryName                           knownForTitles
# 0     nm1774132    Nathan McLaughlin  tt0417686,tt1713976,tt1891860,tt0454839
# 1    nm10683464        Bridge Andrew                                tt7718088
# 2     nm1021485    Brandon Fransvaag                                tt0168790
# 3     nm6940929   Erwin van der Lely                                tt4232168
# 4     nm5764974  Svetlana Shypitsyna                                tt3014168
# ..          ...                  ...                                      ...
# 995   nm7596674         Paul Whitrow  tt4118352,tt9104322,tt4447090,tt4892804
# 996   nm5938546          Wendy Ponce                                tt2125666
# 997   nm2101810         Ans Brugmans                                tt0488280
# 998   nm5245804        Eliza Jenkins                                tt1464058
# 999   nm0948460           Greg Yolen  tt0436869,tt0476663,tt0109723,tt0364484
#
# [1000 rows x 3 columns]

# %%
print(name_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nconst          1000 non-null   object
#  1   primaryName     1000 non-null   object
#  2   knownForTitles  1000 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB
# None

# %%
name_df['knownForTitles'].apply(lambda x: len(x.split(','))).unique()
name_df['knownForTitles'] = name_df['knownForTitles'].apply(lambda x: x.split(','))
name_df
# Out:
#          nconst          primaryName  \
# 0     nm1774132    Nathan McLaughlin
# 1    nm10683464        Bridge Andrew
# 2     nm1021485    Brandon Fransvaag
# 3     nm6940929   Erwin van der Lely
# 4     nm5764974  Svetlana Shypitsyna
# ..          ...                  ...
# 995   nm7596674         Paul Whitrow
# 996   nm5938546          Wendy Ponce
# 997   nm2101810         Ans Brugmans
# 998   nm5245804        Eliza Jenkins
# 999   nm0948460           Greg Yolen
#
#                                    knownForTitles
# 0    [tt0417686, tt1713976, tt1891860, tt0454839]
# 1                                     [tt7718088]
# 2                                     [tt0168790]
# 3                                     [tt4232168]
# 4                                     [tt3014168]
# ..                                            ...
# 995  [tt4118352, tt9104322, tt4447090, tt4892804]
# 996                                   [tt2125666]
# 997                                   [tt0488280]
# 998                                   [tt1464058]
# 999  [tt0436869, tt0476663, tt0109723, tt0364484]
#
# [1000 rows x 3 columns]

# %%
print(name_df.isnull().sum())
# Out:
# nconst            0
# primaryName       0
# knownForTitles    0
# dtype: int64

# %% [markdown]
# ### Joining Datasets

# %%
def unnest_dataframe(df, column):
    df_uni = []
    idx = df.index.repeat(df[column].str.len())
    df1 = pd.DataFrame({column: np.concatenate(df[column].values)})
    df1.index = idx
    df_uni.append(df1)
    df_concat = pd.concat(df_uni, axis=1)
    unnested_df = df_concat.join(df.drop([column], axis=1), how='left')
    return unnested_df[df.columns.tolist()]

unnested_df = name_df.explode('knownForTitles')
unnested_df
# Out:
#          nconst        primaryName knownForTitles
# 0     nm1774132  Nathan McLaughlin      tt0417686
# 0     nm1774132  Nathan McLaughlin      tt1713976
# 0     nm1774132  Nathan McLaughlin      tt1891860
# 0     nm1774132  Nathan McLaughlin      tt0454839
# 1    nm10683464      Bridge Andrew      tt7718088
# ..          ...                ...            ...
# 998   nm5245804      Eliza Jenkins      tt1464058
# 999   nm0948460         Greg Yolen      tt0436869
# 999   nm0948460         Greg Yolen      tt0476663
# 999   nm0948460         Greg Yolen      tt0109723
# 999   nm0948460         Greg Yolen      tt0364484
#
# [1918 rows x 3 columns]

# %%
unnested_drop = unnested_df.drop(['nconst'], axis=1)
df_grouped = unnested_drop.groupby('knownForTitles')['primaryName'].agg(list).reset_index()
df_grouped.columns = ['knownForTitles', 'cast_name']
df_grouped
# Out:
#      knownForTitles           cast_name
# 0         tt0008125    [Charles Harley]
# 1         tt0009706    [Charles Harley]
# 2         tt0010304  [Natalie Talmadge]
# 3         tt0011414  [Natalie Talmadge]
# 4         tt0011890  [Natalie Talmadge]
# ...             ...                 ...
# 1893      tt9610496  [Stefano Baffetti]
# 1894      tt9714030        [Kevin Kain]
# 1895      tt9741820   [Caroline Plyler]
# 1896      tt9759814     [Ethan Francis]
# 1897      tt9856236     [Nuala Maguire]
#
# [1898 rows x 2 columns]

# %%
base_df = pd.merge(df_grouped, movie_rating_df, left_on='knownForTitles', right_on='tconst', how='inner')
base_df = pd.merge(base_df, director_writers, left_on='tconst', right_on='tconst', how='left')
base_df
# Out:
#      knownForTitles              cast_name     tconst     titleType  \
# 0         tt0011414     [Natalie Talmadge]  tt0011414         movie
# 1         tt0011890     [Natalie Talmadge]  tt0011890         movie
# 2         tt0014341     [Natalie Talmadge]  tt0014341         movie
# 3         tt0018054        [Reeka Roberts]  tt0018054         movie
# 4         tt0024151        [James Hackett]  tt0024151         movie
# ...             ...                    ...        ...           ...
# 1055      tt9246600       [Vanessa Hanson]  tt9246600      tvSeries
# 1056      tt9278408          [Utku Arslan]  tt9278408  tvMiniSeries
# 1057      tt9285882     [Jonathon Deering]  tt9285882         movie
# 1058      tt9310372         [Sandini Dhar]  tt9310372      tvSeries
# 1059      tt9355200  [Lars-Gunnar Thorell]  tt9355200         movie
#
#                 primaryTitle           originalTitle  isAdult  startYear  \
# 0            The Love Expert         The Love Expert        0     1920.0
# 1                  Yes or No               Yes or No        0     1920.0
# 2            Our Hospitality         Our Hospitality        0     1923.0
# 3          The King of Kings       The King of Kings        0     1927.0
# 4     I Cover the Waterfront  I Cover the Waterfront        0     1933.0
# ...                      ...                     ...      ...        ...
# 1055             UFC on ESPN             UFC on ESPN        0     2019.0
# 1056                  Bozkir                  Bozkir        0     2018.0
# 1057              Blue Story              Blue Story        0     2019.0
# 1058              Typewriter              Typewriter        0     2019.0
# 1059         Koko-di Koko-da         Koko-di Koko-da        0     2019.0
#
#       endYear  runtimeMinutes                   genres  averageRating  \
# 0      1920.0            60.0           Comedy,Romance            4.9
# 1      1920.0            72.0                  Unknown            6.3
# 2      1923.0            65.0  Comedy,Romance,Thriller            7.8
# 3      1927.0           155.0  Biography,Drama,History            7.3
# 4      1933.0            80.0            Drama,Romance            6.3
# ...       ...             ...                      ...            ...
# 1055   2019.0           180.0                  Unknown            8.1
# 1056   2019.0            50.0      Crime,Drama,Mystery            8.2
# 1057   2019.0            91.0              Crime,Drama            5.5
# 1058   2019.0            48.0          Horror,Thriller            6.5
# 1059   2019.0            86.0    Comedy,Fantasy,Horror            6.2
#
#       numVotes                      director_name  \
# 0          136                   [David Kirkland]
# 1            7                [Roy William Neill]
# 2         9621  [Buster Keaton, John G. Blystone]
# 3         1826                 [Cecil B. DeMille]
# 4          455                      [James Cruze]
# ...        ...                                ...
# 1055        38                                NaN
# 1056      1231                     [Bahadir Ince]
# 1057      1411                           [Rapman]
# 1058      2895                      [Sujoy Ghosh]
# 1059       779                  [Johannes Nyholm]
#
#                                             writer_name
# 0                            [John Emerson, Anita Loos]
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                   [Jeanie Macpherson]
# 4                  [Max Miller, Wells Root, Jack Jevne]
# ...                                                 ...
# 1055                                                NaN
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 1057                                           [Rapman]
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 1059                                  [Johannes Nyholm]
#
# [1060 rows x 15 columns]

# %%
base_drop = base_df.drop(['knownForTitles'], axis=1)
print(base_drop.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cast_name       1060 non-null   object
#  1   tconst          1060 non-null   object
#  2   titleType       1060 non-null   object
#  3   primaryTitle    1060 non-null   object
#  4   originalTitle   1060 non-null   object
#  5   isAdult         1060 non-null   int64
#  6   startYear       1060 non-null   float64
#  7   endYear         1060 non-null   float64
#  8   runtimeMinutes  1060 non-null   float64
#  9   genres          1060 non-null   object
#  10  averageRating   1060 non-null   float64
#  11  numVotes        1060 non-null   int64
#  12  director_name   986 non-null    object
#  13  writer_name     986 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 116.1+ KB
# None

# %%
base_drop[['director_name','writer_name']] = base_drop[['director_name','writer_name']].fillna('unknown')
base_drop['genres'] = base_drop['genres'].apply(lambda x: x.split(','))

# %%
print(base_drop.isnull().sum())
# Out:
# cast_name         0
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# averageRating     0
# numVotes          0
# director_name     0
# writer_name       0
# dtype: int64

# %%
base_drop = base_drop[['primaryTitle','titleType','startYear','runtimeMinutes','genres','averageRating','numVotes','cast_name','director_name','writer_name']]
base_drop.columns = ['title','type','start','duration','genres','rating','votes','cast_name','director_name','writer_name']
base_drop
# Out:
#                        title          type   start  duration  \
# 0            The Love Expert         movie  1920.0      60.0
# 1                  Yes or No         movie  1920.0      72.0
# 2            Our Hospitality         movie  1923.0      65.0
# 3          The King of Kings         movie  1927.0     155.0
# 4     I Cover the Waterfront         movie  1933.0      80.0
# ...                      ...           ...     ...       ...
# 1055             UFC on ESPN      tvSeries  2019.0     180.0
# 1056                  Bozkir  tvMiniSeries  2018.0      50.0
# 1057              Blue Story         movie  2019.0      91.0
# 1058              Typewriter      tvSeries  2019.0      48.0
# 1059         Koko-di Koko-da         movie  2019.0      86.0
#
#                            genres  rating  votes              cast_name  \
# 0               [Comedy, Romance]     4.9    136     [Natalie Talmadge]
# 1                       [Unknown]     6.3      7     [Natalie Talmadge]
# 2     [Comedy, Romance, Thriller]     7.8   9621     [Natalie Talmadge]
# 3     [Biography, Drama, History]     7.3   1826        [Reeka Roberts]
# 4                [Drama, Romance]     6.3    455        [James Hackett]
# ...                           ...     ...    ...                    ...
# 1055                    [Unknown]     8.1     38       [Vanessa Hanson]
# 1056      [Crime, Drama, Mystery]     8.2   1231          [Utku Arslan]
# 1057               [Crime, Drama]     5.5   1411     [Jonathon Deering]
# 1058           [Horror, Thriller]     6.5   2895         [Sandini Dhar]
# 1059    [Comedy, Fantasy, Horror]     6.2    779  [Lars-Gunnar Thorell]
#
#                           director_name  \
# 0                      [David Kirkland]
# 1                   [Roy William Neill]
# 2     [Buster Keaton, John G. Blystone]
# 3                    [Cecil B. DeMille]
# 4                         [James Cruze]
# ...                                 ...
# 1055                            unknown
# 1056                     [Bahadir Ince]
# 1057                           [Rapman]
# 1058                      [Sujoy Ghosh]
# 1059                  [Johannes Nyholm]
#
#                                             writer_name
# 0                            [John Emerson, Anita Loos]
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                   [Jeanie Macpherson]
# 4                  [Max Miller, Wells Root, Jack Jevne]
# ...                                                 ...
# 1055                                            unknown
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 1057                                           [Rapman]
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 1059                                  [Johannes Nyholm]
#
# [1060 rows x 10 columns]

# %% [markdown]
# ## Feature Engineering

# %%
feature_df = base_drop[['title','cast_name','genres','director_name','writer_name', 'rating', 'votes']]
feature_df
# Out:
#                        title              cast_name  \
# 0            The Love Expert     [Natalie Talmadge]
# 1                  Yes or No     [Natalie Talmadge]
# 2            Our Hospitality     [Natalie Talmadge]
# 3          The King of Kings        [Reeka Roberts]
# 4     I Cover the Waterfront        [James Hackett]
# ...                      ...                    ...
# 1055             UFC on ESPN       [Vanessa Hanson]
# 1056                  Bozkir          [Utku Arslan]
# 1057              Blue Story     [Jonathon Deering]
# 1058              Typewriter         [Sandini Dhar]
# 1059         Koko-di Koko-da  [Lars-Gunnar Thorell]
#
#                            genres                      director_name  \
# 0               [Comedy, Romance]                   [David Kirkland]
# 1                       [Unknown]                [Roy William Neill]
# 2     [Comedy, Romance, Thriller]  [Buster Keaton, John G. Blystone]
# 3     [Biography, Drama, History]                 [Cecil B. DeMille]
# 4                [Drama, Romance]                      [James Cruze]
# ...                           ...                                ...
# 1055                    [Unknown]                            unknown
# 1056      [Crime, Drama, Mystery]                     [Bahadir Ince]
# 1057               [Crime, Drama]                           [Rapman]
# 1058           [Horror, Thriller]                      [Sujoy Ghosh]
# 1059    [Comedy, Fantasy, Horror]                  [Johannes Nyholm]
#
#                                             writer_name  rating  votes
# 0                            [John Emerson, Anita Loos]     4.9    136
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]     6.3      7
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...     7.8   9621
# 3                                   [Jeanie Macpherson]     7.3   1826
# 4                  [Max Miller, Wells Root, Jack Jevne]     6.3    455
# ...                                                 ...     ...    ...
# 1055                                            unknown     8.1     38
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]     8.2   1231
# 1057                                           [Rapman]     5.5   1411
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...     6.5   2895
# 1059                                  [Johannes Nyholm]     6.2    779
#
# [1060 rows x 7 columns]

# %%
def sanitize(x):
    try:
        if isinstance(x, list):
            return [i.replace(' ', '').lower() for i in x]
        else:
            return [x.replace(' ', '').lower()]
    except Exception as e:
        print(f"Error saat membersihkan data: {e}, data: {x}")
        return []
feature_df['soup'] = feature_df.apply(lambda x: ' '.join(sanitize(x['cast_name'])) + ' ' + ' '.join(sanitize(x['genres'])) + ' ' + ' '.join(sanitize(x['director_name'])) + ' ' + ' '.join(sanitize(x['writer_name'])), axis=1)
feature_df
# Out:
# <ipython-input-22-5dd29a47ef7b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_df['soup'] = feature_df.apply(lambda x: ' '.join(sanitize(x['cast_name'])) + ' ' + ' '.join(sanitize(x['genres'])) + ' ' + ' '.join(sanitize(x['director_name'])) + ' ' + ' '.join(sanitize(x['writer_name'])), axis=1)
#                        title              cast_name  \
# 0            The Love Expert     [Natalie Talmadge]
# 1                  Yes or No     [Natalie Talmadge]
# 2            Our Hospitality     [Natalie Talmadge]
# 3          The King of Kings        [Reeka Roberts]
# 4     I Cover the Waterfront        [James Hackett]
# ...                      ...                    ...
# 1055             UFC on ESPN       [Vanessa Hanson]
# 1056                  Bozkir          [Utku Arslan]
# 1057              Blue Story     [Jonathon Deering]
# 1058              Typewriter         [Sandini Dhar]
# 1059         Koko-di Koko-da  [Lars-Gunnar Thorell]
#
#                            genres                      director_name  \
# 0               [Comedy, Romance]                   [David Kirkland]
# 1                       [Unknown]                [Roy William Neill]
# 2     [Comedy, Romance, Thriller]  [Buster Keaton, John G. Blystone]
# 3     [Biography, Drama, History]                 [Cecil B. DeMille]
# 4                [Drama, Romance]                      [James Cruze]
# ...                           ...                                ...
# 1055                    [Unknown]                            unknown
# 1056      [Crime, Drama, Mystery]                     [Bahadir Ince]
# 1057               [Crime, Drama]                           [Rapman]
# 1058           [Horror, Thriller]                      [Sujoy Ghosh]
# 1059    [Comedy, Fantasy, Horror]                  [Johannes Nyholm]
#
#                                             writer_name  rating  votes  \
# 0                            [John Emerson, Anita Loos]     4.9    136
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]     6.3      7
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...     7.8   9621
# 3                                   [Jeanie Macpherson]     7.3   1826
# 4                  [Max Miller, Wells Root, Jack Jevne]     6.3    455
# ...                                                 ...     ...    ...
# 1055                                            unknown     8.1     38
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]     8.2   1231
# 1057                                           [Rapman]     5.5   1411
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...     6.5   2895
# 1059                                  [Johannes Nyholm]     6.2    779
#
#                                                    soup
# 0     natalietalmadge comedy romance davidkirkland j...
# 1     natalietalmadge unknown roywilliamneill arthur...
# 2     natalietalmadge comedy romance thriller buster...
# 3     reekaroberts biography drama history cecilb.de...
# 4     jameshackett drama romance jamescruze maxmille...
# ...                                                 ...
# 1055              vanessahanson unknown unknown unknown
# 1056  utkuarslan crime drama mystery bahadirince lev...
# 1057          jonathondeering crime drama rapman rapman
# 1058  sandinidhar horror thriller sujoyghosh sujoygh...
# 1059  lars-gunnarthorell comedy fantasy horror johan...
#
# [1060 rows x 8 columns]

# %% [markdown]
# ## Modeling and Evaluation

# %%
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(feature_df['soup'])

print(count)
print(count_matrix.shape)
# Out:
# CountVectorizer(stop_words='english')
# (1060, 10026)

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)
print(cosine_sim)
# Out:
# [[1.         0.15430335 0.35355339 ... 0.         0.         0.13608276]
#  [0.15430335 1.         0.10910895 ... 0.         0.         0.        ]
#  [0.35355339 0.10910895 1.         ... 0.         0.08703883 0.09622504]
#  ...
#  [0.         0.         0.         ... 1.         0.         0.        ]
#  [0.         0.         0.08703883 ... 0.         1.         0.10050378]
#  [0.13608276 0.         0.09622504 ... 0.         0.10050378 1.        ]]

# %% [markdown]
# ## Recommendation Function

# %%
indices = pd.Series(feature_df.index, index=feature_df['title']).drop_duplicates()

def content_recommender(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    return base_df.iloc[movie_indices]

# %%
movie_title = input("Masukkan judul film: ")
recommendations = content_recommender(movie_title)
print("\nRekomendasi film yang mirip dengan", movie_title + ":")
recommendations
# Out:
# Masukkan judul film: Typewriter
#
# Rekomendasi film yang mirip dengan Typewriter:
#      knownForTitles               cast_name     tconst titleType  \
# 1030      tt8130968          [Sandini Dhar]  tt8130968     movie
# 246       tt0124102            [Lois Hicks]  tt0124102     movie
# 833       tt2791026  [Santiago López Gómez]  tt2791026     movie
# 171       tt0101981          [Wai Chi Wong]  tt0101981     movie
# 202       tt0109723            [Greg Yolen]  tt0109723     movie
# 665       tt1523584          [Daniel Boyle]  tt1523584     video
# 942       tt5165620       [Dan Frishwasser]  tt5165620     movie
# 971       tt6063742        [Rebecca Hickey]  tt6063742  tvSeries
# 518       tt0808315      [Michael Steinitz]  tt0808315     movie
# 875       tt3483644       [Krystal Ellison]  tt3483644     movie
#
#                 primaryTitle           originalTitle  isAdult  startYear  \
# 1030                   Badla                   Badla        0     2019.0
# 246              Strangeland             Strangeland        0     1998.0
# 833         City of Dead Men        City of Dead Men        0     2014.0
# 171               Gui gan bu              Gui gan bu        0     1991.0
# 202   Embrace of the Vampire  Embrace of the Vampire        0     1995.0
# 665           Deadly Weekend          Deadly Weekend        0     2014.0
# 942             Another Soul            Another Soul        0     2018.0
# 971            Urban Legends           Urban Legends        0     2016.0
# 518           Dead in 3 Days  In 3 Tagen bist du tot        0     2006.0
# 875                  Slasher                 Slasher        0     2014.0
#
#       endYear  runtimeMinutes                   genres  averageRating  \
# 1030   2019.0           118.0      Crime,Drama,Mystery            7.9
# 246    1998.0            85.0          Horror,Thriller            5.2
# 833    2014.0            87.0          Horror,Thriller            3.8
# 171    1991.0            93.0          Horror,Thriller            5.5
# 202    1995.0            92.0          Horror,Thriller            4.4
# 665    2014.0            82.0          Horror,Thriller            2.8
# 942    2018.0            78.0          Horror,Thriller            2.1
# 971    2016.0             5.0          Horror,Thriller            8.8
# 518    2006.0            97.0          Horror,Thriller            5.5
# 875    2014.0            93.0  Horror,Mystery,Thriller            7.3
#
#       numVotes        director_name  \
# 1030     18452        [Sujoy Ghosh]
# 246       6417       [John Pieplow]
# 833        462      [Kirk Sullivan]
# 171         56      [Yeung-Wah Kam]
# 202       5714      [Anne Goursaud]
# 665        562       [Jason Sutton]
# 942        222          [Paul Chau]
# 971         30        [Luke Mordue]
# 518       2352  [Andreas Prochaska]
# 875         22     [Jonathan Rowan]
#
#                                          writer_name
# 1030          [Oriol Paulo, Sujoy Ghosh, Raj Vasant]
# 246                                     [Dee Snider]
# 833                                  [Andrew Poston]
# 171                                    [Pik Wah Lee]
# 202   [Halle Eaton, Nicole Coady, Rick Bitzelberger]
# 665                                   [Jason Sutton]
# 942                                      [Paul Chau]
# 971                                    [Luke Mordue]
# 518                 [Thomas Baum, Andreas Prochaska]
# 875                                 [Jonathan Rowan]
